# %% [markdown]
# # NEON Paper Plots (Light Use Efficiency Curve)
# ## Figure 7: LUE boxplots
#   + Figure 7 Alternatives
# ##### Author : Negin Sobhani negins@ucar.edu [@negin513](https://github.com/negin513)
#
# ##### Last revised: 2023-01-13
# _______
#
# This notebooks have the scripts for:
#
# 1. Creating light use efficiency curves using specified bins
# 2. Filtering light use efficiency curves.
#
# TODO, this script still fails for sites with incomplete data records. Additional modifications are needed for these exceptions

# %%
import os
import time
import datetime

import numpy as np
import pandas as pd
import xarray as xr

from glob import glob
from os.path import join

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)


import calendar

import tqdm
import cftime
from neon_utils import download_eval_files

import seaborn as sns ## -- seaborn only needed for boxplots:

# %%
print('xarray '+xr.__version__) ##-- was working with 0.20.0
# Out:
# xarray 2022.6.0

# %% [markdown]
# ## Dask Cluster
# The following will spin up a dask cluster,  only works on NCAR machines.
# 16 workers worked best for NEON.

# %%
from distributed import Client
from ncar_jobqueue import NCARCluster

cluster = NCARCluster()
cluster.scale(16)
client = Client(cluster)
client
# Out:
# /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41288 instead
#   warnings.warn(
# <Client: 'tcp://10.12.206.49:46257' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ---------------------------
# ## Make Light Use Efficiency Curve Boxplots

# %%
# -- read list of sites:
#neon_sites_pft = pd.read_csv('/glade/scratch/negins/preprocessed_neon_csv_data/neon_sites_dompft.csv')
neon_sites_pft = pd.read_csv('/glade/u/home/wwieder/CTSM/tools/site_and_regional/neon_sites_dompft.csv')
neon_sites = neon_sites_pft['Site'].to_list()

failed_sites = [] # -- list for saving failed sites

# %%
# -- read only these variables from the whole netcdf files
def preprocess (ds):
    variables = ['GPP','ELAI']

    ds_new= ds[variables]
    return ds_new

# %%
out_dir = "/glade/work/wwieder/neon_vis_plots/paper_plots_final/"

if not os.path.exists (out_dir):
    print ("plot directory does not exist... creating it now!")
    os.mkdir(out_dir)

# %%
## -- Setting some defaults for our figures:
plt.rcParams["font.weight"] = "bold"    
plt.rcParams["axes.labelweight"] = "bold"
font = {'weight' : 'bold',
        'size'   : 15} 
matplotlib.rc('font', **font)

# %%
#neon_sites = ['BART'] # for testing
years = ["2018","2019","2020","2021"]
months = ["07","08"]
save_switch = True

for neon_site in neon_sites:
    try: 
        start_site = time.time()
        print ('---------------------------')
        print ("Making plots for "+neon_site)

        sim_path = "/glade/campaign/cgd/tss/wwieder/NEON_v2/hist/"+neon_site+".transient/lnd/hist/"
        #sim_path = "/glade/scratch/wwieder/run_NEON_v2/tools/site_and_regional/archive/"+neon_site+".transient/lnd/hist/"
        #sim_path = "/glade/scratch/negins/neon_v2/tools/site_and_regional/archive/"+neon_site+".transient/lnd/hist/"

        sim_files = []
        for year in years:
            for month in months:
                sim_files.extend(sorted(glob(join(sim_path,neon_site+".transient.clm2.h1."+year+"-"+month+"*.nc"))))

        print("All Simulation files for all years: [", len(sim_files), "files]")

        start = time.time()

        ds_ctsm = xr.open_mfdataset(sim_files, decode_times=True, combine='by_coords',parallel=True, preprocess=preprocess)

        end = time.time()
        print("Reading all simulation files took:", end-start, "s.")


        eval_dir = "/glade/campaign/cgd/tss/wwieder/NEON_v2/eval/"
        #eval_dir = "/glade/work/wwieder/neon/eval_files/"
        #eval_dir = "/glade/work/negins/neon_scripts/notebooks/evaluation_files_2/"
        eval_path = os.path.join(eval_dir,neon_site)

        eval_files = []
        for year in years:
            for month in months:
                eval_files.extend(sorted(glob(join(eval_path,neon_site+"_eval_"+year+"-"+month+".nc"))))

        start = time.time()

        ds_eval = xr.open_mfdataset(eval_files, decode_times=True, combine='by_coords')

        end = time.time()
        print("Reading all observation files took:", end-start, "s.")

        # For datm files in run directories
        #atm_dir = "/glade/scratch/wwieder/NEON_testV2/"
        #atm_suf = neon_site+".transient/run/inputdata/atm/cdeps/v2/"
        #atm_path = os.path.join(atm_dir, atm_suf, neon_site)

        # For datm files dowloaded directly
        atm_dir = "/glade/campaign/cgd/tss/wwieder/NEON_v2/datm"
        atm_path = os.path.join(atm_dir, neon_site)

        atm_files = []
        for year in years:
            for month in months:
                atm_files.extend(sorted(glob(join(atm_path,neon_site+"_atm_"+year+"-"+month+".nc"))))

        start = time.time()

        ds_atm = xr.open_mfdataset(atm_files, decode_times=True, combine='by_coords')

        end = time.time()
        print("Reading all forcing files took:", end-start, "s.")


        #Convert CTSM data to a Pandas Dataframe for easier handling:
        ctsm_vars = ['GPP']

        df_ctsm = pd.DataFrame({'time':ds_ctsm.time})

        for var in ctsm_vars:
            field = np.ravel ( ds_ctsm[var])     
            df_ctsm[var]=field


        #-- make df_all that includes both obs and sim
        df_all = df_ctsm

        atm_vars = ['FSDS']

        for var in atm_vars:
            field = np.ravel ( ds_atm[var])     
            df_all[var]=field

        eval_vars=['GPP']
        for var in eval_vars:
            field = np.ravel ( ds_eval[var])
            obs_var = 'obs_'+var
            df_all[obs_var]=field


        #-- extract year, month, day, hour information from time
        df_all['year'] = df_all['time'].dt.year
        df_all['month'] = df_all['time'].dt.month
        df_all['day'] = df_all['time'].dt.day
        df_all['hour'] = df_all['time'].dt.hour

        df_all['season'] = ((df_all['month']%12+3)//3).map({1:'DJF', 2: 'MAM', 3:'JJA', 4:'SON'})

        # convert NEE units from  umolm-2s-1 to gc/m2/s
        df_all ['obs_GPP']= df_all ['obs_GPP']*(12.01/1000000)

        #convert to perday instead per second
        df_all ['GPP']= df_all['GPP']*60*60*24
        df_all ['obs_GPP']= df_all['obs_GPP']*60*60*24

        df_all['Month'] = df_all['month'].apply(lambda x: calendar.month_abbr[x])

        # --filtering GPP and obs_GPP to >0:
        df_all = df_all[df_all["obs_GPP"]>0]
        df_all = df_all[df_all["GPP"]>0]
        df_all = df_all[df_all["FSDS"]>0]

        # -- filtering only for July values:
        df_all = df_all[df_all["month"]==7]

        
        fig = plt.figure(num=None, figsize=(15, 7.5),  facecolor='w', edgecolor='k')
        axes = fig.subplots(nrows=1, ncols=2)
        axe = axes.ravel()

        sns.regplot(data=df_all, x="FSDS", y="GPP",  ax=axe[0],label='CLM',fit_reg=False,scatter_kws={"s": 80})
        #sns.scatterplot(x=df_all['FSDS'],ax=ax, y=df_all['obs_GPP'])

        axe[0].set(xlabel='Incident Shortwave [Wm⁻²]')
        plot_var_desc = "Gross Primary Production"
        plot_var_unit= "gC m⁻²day⁻¹"
        axe[0].set(ylabel = plot_var_desc +" ["+plot_var_unit+"]")
        #axe[0].set(title = "NEON site : "+neon_site +" JJA",fontsize=19)
        axe[0].set_ylim(-3, 30)

        plot_var_desc = "Gross Primary Production"
        plot_var_unit= "gC m⁻²day⁻¹"
        axe[0].set(ylabel = plot_var_desc +" ["+plot_var_unit+"]")

        sns.regplot(data=df_all, x="FSDS", y="obs_GPP", ax=axe[1], color='orange',label='NEON',fit_reg=False,scatter_kws={"s": 80})

        axe[1].set(xlabel='Incident Shortwave [Wm⁻²]')
        plot_var_desc = "Gross Primary Production"
        plot_var_unit= "gC m⁻²day⁻¹"
        axe[1].set(ylabel = plot_var_desc +" ["+plot_var_unit+"]")
        axe[1].set_ylim(-3, 50)
        fig.suptitle('NEON site : '+neon_site +" JJA",fontweight='bold',fontsize=15,y=0.99)

        lines_labels = [ax.get_legend_handles_labels() for ax in axe]
        #print (lines)
        lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]

        for idx, ax in enumerate(axe):
            ax.set_xlabel('Incident Shortwave [Wm⁻²]', fontsize=17)
            ax.set_xlabel('Incident Shortwave [Wm⁻²]', fontsize=17)
            ax.set_ylim(-3, 50)
            ax.tick_params(right= True,left= True, bottom= True)

            if idx == 0:
                ax.set_ylabel( plot_var_desc +" ["+plot_var_unit+"]",fontsize=17 )
                ax.tick_params(axis='y',which = 'both', direction="in")

            else:
                ax.set_ylabel('')
                ax.set_yticklabels([])
                ax.tick_params(axis='y',which = 'both', direction="in")

        #ax.tick_params(right= True,left= True, bottom= True)

        fig.subplots_adjust(wspace=0, hspace=0)
        fig.suptitle('Neon site : '+ neon_site +'\n 2018-2021 July (Filtered)', fontweight='bold',fontsize=17)

        if save_switch:
            plot_dir = os.path.join(out_dir, 'light_use_curve_scatter', 'png')
            
            if not os.path.isdir(plot_dir):
                os.makedirs(plot_dir, exist_ok=True)
            plot_name = neon_site+'_'+'light_use_curve_scatter.png'
            print ('Saving '+ os.path.join(plot_dir,plot_name))
    
            plt.savefig (os.path.join(plot_dir,plot_name), dpi=600,bbox_inches='tight')
        else:    
            plt.show()

        from scipy import stats

        fig = plt.figure(num=None, figsize=(15, 7.5),  facecolor='w', edgecolor='k')
        axes = fig.subplots(nrows=1, ncols=2)
        axe = axes.ravel()

        slope, intercept, r_value, pv, se = stats.linregress(np.log(df_all['FSDS']), df_all['GPP'])

        sns.regplot(data=df_all, x="FSDS", y="GPP",  ax=axe[0],label='CLM',scatter_kws={"s": 80}, logx=True,x_bins=7, truncate=True,line_kws={'label':'CLM : $y=%3.5s + %3.5s.log(x)$'%(intercept, slope)}, ci =99, x_ci= 99)
        #sns.scatterplot(x=df_all['FSDS'],ax=ax, y=df_all['obs_GPP'])

        axe[0].set(xlabel='Incident Shortwave [Wm⁻²]')
        plot_var_desc = "Gross Primary Production"
        plot_var_unit= "gC m⁻²day⁻¹"
        axe[0].set(ylabel = plot_var_desc +" ["+plot_var_unit+"]")
        #axe[0].set(title = "NEON site : "+neon_site +" JJA",fontsize=19)
        axe[0].set_ylim(-3, 30)

        plot_var_desc = "Gross Primary Production"
        plot_var_unit= "gC m⁻²day⁻¹"
        axe[0].set(ylabel = plot_var_desc +" ["+plot_var_unit+"]")

        slope, intercept, r_value, pv, se = stats.linregress(np.log(df_all['FSDS']), df_all['obs_GPP'])

        p1 = sns.regplot(data=df_all, x="FSDS", y="obs_GPP", ax=axe[1], color='orange',label='NEON',scatter_kws={"s": 80},logx=True,x_bins=7, truncate=True,line_kws={'label':'NEON : $y=%3.5s + %3.5s.log(x)$'%(intercept, slope)}, ci =99, x_ci= 99)


        axe[1].set(xlabel='Incident Shortwave [Wm⁻²]')
        plot_var_desc = "Gross Primary Production"
        plot_var_unit= "gC m⁻²day⁻¹"
        axe[1].set(ylabel = plot_var_desc +" ["+plot_var_unit+"]")
        axe[1].set_ylim(-3, 50)
        fig.suptitle('NEON site : '+neon_site +" JJA",fontweight='bold',fontsize=15,y=0.99)

        lines_labels = [ax.get_legend_handles_labels() for ax in axe]
        lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]

        for idx, ax in enumerate(axe):
            ax.set_xlabel('Incident Shortwave [Wm⁻²]', fontsize=17)
            ax.set_xlabel('Incident Shortwave [Wm⁻²]', fontsize=17)
            ax.set_ylim(-2, 30)
            ax.tick_params(right= True,left= True, bottom= True)

            if idx == 0:
                ax.set_ylabel( plot_var_desc +" ["+plot_var_unit+"]",fontsize=17 )
                ax.tick_params(axis='y',which = 'both', direction="in")

            else:
                ax.set_ylabel('')
                ax.set_yticklabels([])
                ax.tick_params(axis='y',which = 'both', direction="in")

        #ax.tick_params(right= True,left= True, bottom= True)


        fig.subplots_adjust(wspace=0, hspace=0)
        fig.suptitle('Neon site : '+ neon_site +'\n 2018-2021 July (Filtered)', fontweight='bold',fontsize=17)

        plt.legend(lines, labels)

        if save_switch:
            plot_dir = os.path.join(out_dir, 'light_use_curve_scatter_fitted_log_line', 'png')
            
            if not os.path.isdir(plot_dir):
                os.makedirs(plot_dir, exist_ok=True)
            plot_name = neon_site+'_'+'light_use_curve_scatter_fitted_log_line.png'
            print ('Saving '+ os.path.join(plot_dir,plot_name))

            plt.savefig (os.path.join(plot_dir,plot_name), dpi=300,bbox_inches='tight')
        else:
            plt.show()
        

        bins = [0, 25., 50, 100, 200, 300, 400,1000]

        df_all['bins_FSDS'] = pd.cut(df_all['FSDS'], bins)


        df_bins = df_all
        df_bins['bin'] = pd.cut(df_all['FSDS'], bins)


        mid_bins = [12.5,37.5, 75., 150, 250, 350, 450]

        df_bins['bin'] = pd.cut(df_all['FSDS'], bins,labels=mid_bins)


        fig = plt.figure(num=None, figsize=(11, 5.9),  facecolor='w', edgecolor='k')
        axe = plt.gca()

        flyprops = {'markersize':0.01}
        my_pal = {'obs_GPP': "darkorange", 'GPP': "steelblue"}

        colorprops = {'color':'steelblue'}


        mid_bins = [12.5,37.5, 75., 150, 250, 350, 450]
        color1 = 'darkorange'
        color2 = 'steelblue'
        
        color2 = '#1d657e'
        color1 = '#e28743'
        positions=[12.5,37.5, 75., 150, 250, 350, 450] 
        postitions1= [n-6 for n in positions]
        postitions2= [n+12 for n in postitions1]

        colorprops = {'color':'darkorange'}
        boxprops = dict(linestyle='-', linewidth=2, color='k')
        medianprops = dict(linestyle='-', linewidth=2, color='k')

        #sns.regplot(data=df_all, x="FSDS", y="obs_GPP", ax=axe, color=color1,label='NEON',scatter_kws={"s": 80},logx=True, truncate=True, scatter=False, ci = 98)
        #sns.regplot(data=df_all, x="FSDS", y="GPP", ax=axe, color=color2,label='CLM',scatter_kws={"s": 80},logx=True, truncate=True, scatter=False, ci = 98)

        df_bins.boxplot(ax=axe, column = 'obs_GPP',by='bin', positions=postitions1, widths = 11 ,
                patch_artist=True,
                notch=False,
                #flierprops=flyprops,
                showcaps=True,
                showmeans=True,
                showfliers=False, 
                #boxprops=boxprops,
                #medianprops=medianprops,
                #whiskerprops={'color': 'tab:blue'},
                color=dict(boxes="DarkGreen", whiskers="DarkOrange", medians="DarkBlue", caps="Gray"),
                boxprops=dict(linestyle='-', linewidth=1.5,facecolor=color1, color="k"),
                flierprops=dict(linestyle='-', linewidth=1.5,marker='.'),
                medianprops=dict(linestyle='-', linewidth=1.5,color="k"),
                whiskerprops=dict(linestyle='-', linewidth=1.5),
                capprops=dict(linestyle='-', linewidth=1.5),
                meanprops=dict(marker='o', markeredgecolor='black',markerfacecolor='white',markersize=5.5),

                grid=False,
                )
        df_bins.boxplot(ax=axe, column = 'GPP',by='bin', positions=postitions2, widths = 11 ,
                patch_artist=True,
                notch=False,
                #flierprops=flyprops,
                showcaps=True,
                showmeans=True,
                showfliers=False, 
                #boxprops=boxprops,
                #medianprops=medianprops,
                #whiskerprops={'color': 'tab:blue'},
                color=dict(boxes="DarkGreen", whiskers="DarkOrange", medians="DarkBlue", caps="Gray"),
                boxprops=dict(linestyle='-', linewidth=1.5,facecolor=color2, color="k"),
                flierprops=dict(linestyle='-', linewidth=1.5,marker='.'),
                medianprops=dict(linestyle='-', linewidth=1.5,color="k"),
                whiskerprops=dict(linestyle='-', linewidth=1.5),
                capprops=dict(linestyle='-', linewidth=1.5),
                meanprops=dict(marker='o', markeredgecolor='black',markerfacecolor='white',markersize=5.5),

                grid=False,
                )



        axe.set_xlim([-3,500])

        xticks = [0,25,50,100,200,300,400,]
        xticks_labels = [0,25,50,100,200,300, 400,]

        axe.set_xticks(xticks)
        axe.set_xticklabels(xticks_labels)
        axe.set_title('')
        axe.grid(color='gray', linestyle='--', linewidth=0.5)
        axe.yaxis.grid(False, which='major')
        axe.set_ylabel( plot_var_desc +" ["+plot_var_unit+"]",fontsize=13 )
        axe.set_xlabel('Incident Shortwave [Wm⁻²]', fontsize=13)
        plt.suptitle('')
        axe.set_title('Neon site : '+ neon_site +'\n 2018-2021 July', fontweight='bold',fontsize=17)


        red_patch = mpatches.Patch(color=color1, label='NEON')
        blue_patch = mpatches.Patch(color=color2, label='CTSM')
        plt.legend(handles=[red_patch, blue_patch])

        if save_switch:
            plot_dir = os.path.join(out_dir, 'light_use_boxplots_bins_uniform', 'png')
            
            if not os.path.isdir(plot_dir):
                os.makedirs(plot_dir, exist_ok=True)
            plot_name = neon_site+'_'+'light_use_curve_'+'_'+'bins_boxplots_uniform.png'
            print ('Saving '+ os.path.join(plot_dir,plot_name))
            plt.savefig (os.path.join(plot_dir,plot_name), dpi=600,bbox_inches='tight')
            
            
            plot_dir = os.path.join(out_dir, 'light_use_boxplots_bins_uniform', 'pdf')
            
            if not os.path.isdir(plot_dir):
                os.makedirs(plot_dir, exist_ok=True)
            plot_name = neon_site+'_'+'light_use_curve'+'_'+'bins_boxplots_uniform.pdf'
            print ('Saving '+ os.path.join(plot_dir,plot_name))
            plt.savefig (os.path.join(plot_dir,plot_name), dpi=600,bbox_inches='tight', format = 'pdf')
        else:
            plt.show()



        fig = plt.figure(num=None, figsize=(9, 5.9),  facecolor='w', edgecolor='k')
        axe = plt.gca()

        df_plot = df_all.melt(id_vars='bins_FSDS', value_vars=['obs_GPP', 'GPP'])
        my_pal = {'obs_GPP': "darkorange", 'GPP': "steelblue"}

        sns.boxplot(x='bins_FSDS', y='value', hue='variable', data=df_plot,width =0.513,linewidth=3,showfliers = False,palette=my_pal, 
                    showmeans=True,
                    meanprops={"marker":"o",
                    "markerfacecolor":"white", 
                    "markeredgecolor":"black",
                    "markersize":"10"})

        axe.set(xlabel='Incident Shortwave [Wm⁻²]')
        plot_var_desc = "Gross Primary Production"
        plot_var_unit= "gC m⁻²day⁻¹"
        axe.set(ylabel = plot_var_desc +" ["+plot_var_unit+"]")
        #axe[0].set(title = "NEON site : "+neon_site +" JJA",fontsize=19)
        #axe.set_ylim(-1, 30)
        xticks = [0,25,50,100,200,300, 400,]
        xticks_labels = [0,25,50,100,200,300,400,]

        #axe.set_xticks(xticks)
        #axe.set_xticklabels(xticks_labels)
        labels = [item.get_text() for item in axe.get_xticklabels()]

        ticks = [item for item in axe.get_xticks()]
        new_ticks = np.arange(-0.5, len(ticks)-0.5, 1)

        #axe.xaxis.set_minor_locator(AutoMinorLocator())
        axe.set_xticks(new_ticks)


        new_labels = ['        0-25','      25-50','      50-100','    100-200','   200-300', '    300-400','    <400']
        axe.set_xticklabels(new_labels)

        #axe.tick_params(which='minor', length=4, color='r')
        #axe.tick_params(axis='x', which='minor')
        for tick in axe.xaxis.get_majorticklabels():
            tick.set_horizontalalignment("left")

        #axe.set_xticklabels(axe.xaxis.get_majorticklabels(), rotation=45)
        handles, _ = axe.get_legend_handles_labels()          # Get the artists.
        axe.legend(handles, ["NEON", "CTSM"], loc="best") # Associate manually the artists to a label.

        axe.set_title('Neon site : '+ neon_site +'\n 2018-2021 July', fontweight='bold',fontsize=17)

        if save_switch:
            
            plot_dir = os.path.join(out_dir, 'light_use_boxplots_bins_nonuniform', 'png')
            
            if not os.path.isdir(plot_dir):
                os.makedirs(plot_dir, exist_ok=True)
            plot_name = neon_site+'_light_use_boxplots_bins_nonuniform.png'
            print ('Saving '+ os.path.join(plot_dir,plot_name))

            plt.savefig (os.path.join(plot_dir,plot_name), dpi=300,bbox_inches='tight')
        else:
            plt.show()

        end_site = time.time()
        print("Making these plots for "+neon_site+" took : ", end_site-start_site, "s.")


    except Exception as e: 
        print (e)
        print ('THIS SITE FAILED:', neon_site)
        failed_sites.append(neon_site)
        pass
    
    plt.close('all')
print ("Making plots for ", len(failed_sites), "sites failed : ")
print (*failed_sites, sep=" \n")
# Out:
# ---------------------------
# Making plots for BART
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.1563217639923096 s.
# Reading all observation files took: 0.2095813751220703 s.
# Reading all forcing files took: 0.13255906105041504 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/BART_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/BART_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/BART_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/BART_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/BART_light_use_boxplots_bins_nonuniform.png
# Making these plots for BART took :  8.750694036483765 s.
# ---------------------------
# Making plots for HARV
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.090015172958374 s.
# Reading all observation files took: 0.4063537120819092 s.
# Reading all forcing files took: 0.25836968421936035 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/HARV_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/HARV_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/HARV_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/HARV_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/HARV_light_use_boxplots_bins_nonuniform.png
# Making these plots for HARV took :  8.837326765060425 s.
# ---------------------------
# Making plots for BLAN
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 0.9673595428466797 s.
# Reading all observation files took: 0.3146555423736572 s.
# Reading all forcing files took: 0.24743175506591797 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/BLAN_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/BLAN_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/BLAN_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/BLAN_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/BLAN_light_use_boxplots_bins_nonuniform.png
# Making these plots for BLAN took :  7.771254062652588 s.
# ---------------------------
# Making plots for SCBI
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 0.9793491363525391 s.
# Reading all observation files took: 0.3247208595275879 s.
# Reading all forcing files took: 0.2544572353363037 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/SCBI_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/SCBI_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/SCBI_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/SCBI_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/SCBI_light_use_boxplots_bins_nonuniform.png
# Making these plots for SCBI took :  7.84763503074646 s.
# ---------------------------
# Making plots for SERC
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 0.9483175277709961 s.
# Reading all observation files took: 0.5648906230926514 s.
# Reading all forcing files took: 0.25927305221557617 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/SERC_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/SERC_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/SERC_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/SERC_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/SERC_light_use_boxplots_bins_nonuniform.png
# Making these plots for SERC took :  8.03056812286377 s.
# ---------------------------
# Making plots for DSNY
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.3199479579925537 s.
# Reading all observation files took: 0.30686378479003906 s.
# Reading all forcing files took: 0.23520255088806152 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/DSNY_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/DSNY_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/DSNY_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/DSNY_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/DSNY_light_use_boxplots_bins_nonuniform.png
# Making these plots for DSNY took :  7.767348766326904 s.
# ---------------------------
# Making plots for JERC
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.3087677955627441 s.
# Reading all observation files took: 0.3129410743713379 s.
# Reading all forcing files took: 0.25641751289367676 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/JERC_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/JERC_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/JERC_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/JERC_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/JERC_light_use_boxplots_bins_nonuniform.png
# Making these plots for JERC took :  8.382243394851685 s.
# ---------------------------
# Making plots for OSBS
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.1823508739471436 s.
# Reading all observation files took: 0.32225894927978516 s.
# Reading all forcing files took: 0.2376248836517334 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/OSBS_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/OSBS_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/OSBS_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/OSBS_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/OSBS_light_use_boxplots_bins_nonuniform.png
# Making these plots for OSBS took :  7.989257574081421 s.
# ---------------------------
# Making plots for GUAN
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 1.0705697536468506 s.
# Reading all observation files took: 0.3620903491973877 s.
# Reading all forcing files took: 0.26502513885498047 s.
# Length of values (11904) does not match length of index (8928)
# THIS SITE FAILED: GUAN
# ---------------------------
# Making plots for LAJA
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 0.9594097137451172 s.
# Reading all observation files took: 0.28531956672668457 s.
# Reading all forcing files took: 0.3118894100189209 s.
# Length of values (11904) does not match length of index (8928)
# THIS SITE FAILED: LAJA
# ---------------------------
# Making plots for STEI
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.224189281463623 s.
# Reading all observation files took: 0.3314220905303955 s.
# Reading all forcing files took: 0.2843451499938965 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/STEI_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/STEI_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/STEI_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/STEI_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/STEI_light_use_boxplots_bins_nonuniform.png
# Making these plots for STEI took :  9.17566442489624 s.
# ---------------------------
# Making plots for TREE
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.4030096530914307 s.
# Reading all observation files took: 0.28455567359924316 s.
# Reading all forcing files took: 0.2975649833679199 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/TREE_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/TREE_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/TREE_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/TREE_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/TREE_light_use_boxplots_bins_nonuniform.png
# Making these plots for TREE took :  8.59782862663269 s.
# ---------------------------
# Making plots for UNDE
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.7134058475494385 s.
# Reading all observation files took: 0.6971347332000732 s.
# Reading all forcing files took: 0.2660820484161377 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/UNDE_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/UNDE_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/UNDE_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/UNDE_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/UNDE_light_use_boxplots_bins_nonuniform.png
# Making these plots for UNDE took :  9.006690263748169 s.
# ---------------------------
# Making plots for KONA
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 0.9873888492584229 s.
# Reading all observation files took: 0.3401169776916504 s.
# Reading all forcing files took: 0.2618398666381836 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/KONA_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/KONA_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/KONA_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/KONA_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/KONA_light_use_boxplots_bins_nonuniform.png
# Making these plots for KONA took :  7.77048397064209 s.
# ---------------------------
# Making plots for KONZ
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 0.9990839958190918 s.
# Reading all observation files took: 0.3475821018218994 s.
# Reading all forcing files took: 0.2948944568634033 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/KONZ_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/KONZ_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/KONZ_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/KONZ_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/KONZ_light_use_boxplots_bins_nonuniform.png
# Making these plots for KONZ took :  8.768765449523926 s.
# ---------------------------
# Making plots for UKFS
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.57875394821167 s.
# Reading all observation files took: 0.32634687423706055 s.
# Reading all forcing files took: 0.25489234924316406 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/UKFS_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/UKFS_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/UKFS_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/UKFS_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/UKFS_light_use_boxplots_bins_nonuniform.png
# Making these plots for UKFS took :  8.647947072982788 s.
# ---------------------------
# Making plots for GRSM
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.515754222869873 s.
# Reading all observation files took: 0.333815336227417 s.
# Reading all forcing files took: 0.27457427978515625 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/GRSM_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/GRSM_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/GRSM_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/GRSM_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/GRSM_light_use_boxplots_bins_nonuniform.png
# Making these plots for GRSM took :  8.58319902420044 s.
# ---------------------------
# Making plots for MLBS
# All Simulation files for all years: [ 124 files]
# Reading all simulation files took: 2.6586568355560303 s.
# Reading all observation files took: 0.3416450023651123 s.
# Reading all forcing files took: 0.5840706825256348 s.
# Length of values (11904) does not match length of index (5952)
# THIS SITE FAILED: MLBS
# ---------------------------
# Making plots for ORNL
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 2.0009264945983887 s.
# Reading all observation files took: 0.32187700271606445 s.
# Reading all forcing files took: 0.24842143058776855 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/ORNL_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/ORNL_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/ORNL_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/ORNL_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/ORNL_light_use_boxplots_bins_nonuniform.png
# Making these plots for ORNL took :  8.820993900299072 s.
# ---------------------------
# Making plots for DELA
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.0340266227722168 s.
# Reading all observation files took: 0.34773826599121094 s.
# Reading all forcing files took: 0.24315381050109863 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/DELA_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/DELA_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/DELA_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/DELA_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/DELA_light_use_boxplots_bins_nonuniform.png
# Making these plots for DELA took :  8.690007209777832 s.
# ---------------------------
# Making plots for LENO
# All Simulation files for all years: [ 62 files]
# Reading all simulation files took: 0.36827826499938965 s.
# Reading all observation files took: 0.2976205348968506 s.
# Reading all forcing files took: 0.224961519241333 s.
# Length of values (11904) does not match length of index (2976)
# THIS SITE FAILED: LENO
# ---------------------------
# Making plots for TALL
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 0.988593339920044 s.
# Reading all observation files took: 0.349837064743042 s.
# Reading all forcing files took: 0.23048686981201172 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/TALL_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/TALL_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/TALL_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/TALL_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/TALL_light_use_boxplots_bins_nonuniform.png
# Making these plots for TALL took :  7.948476314544678 s.
# ---------------------------
# Making plots for DCFS
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.7832832336425781 s.
# Reading all observation files took: 0.34166812896728516 s.
# Reading all forcing files took: 0.5470232963562012 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/DCFS_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/DCFS_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/DCFS_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/DCFS_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/DCFS_light_use_boxplots_bins_nonuniform.png
# Making these plots for DCFS took :  10.035078763961792 s.
# ---------------------------
# Making plots for NOGP
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.047335147857666 s.
# Reading all observation files took: 0.3166332244873047 s.
# Reading all forcing files took: 0.2806053161621094 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/NOGP_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/NOGP_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/NOGP_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/NOGP_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/NOGP_light_use_boxplots_bins_nonuniform.png
# Making these plots for NOGP took :  7.807906627655029 s.
# ---------------------------
# Making plots for WOOD
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.0316076278686523 s.
# Reading all observation files took: 0.2952389717102051 s.
# Reading all forcing files took: 0.21531248092651367 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/WOOD_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/WOOD_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/WOOD_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/WOOD_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/WOOD_light_use_boxplots_bins_nonuniform.png
# Making these plots for WOOD took :  7.682230472564697 s.
# ---------------------------
# Making plots for CPER
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.7533822059631348 s.
# Reading all observation files took: 0.31746673583984375 s.
# Reading all forcing files took: 0.27692127227783203 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/CPER_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/CPER_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/CPER_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/CPER_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/CPER_light_use_boxplots_bins_nonuniform.png
# Making these plots for CPER took :  8.352389812469482 s.
# ---------------------------
# Making plots for RMNP
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.13059401512146 s.
# Reading all observation files took: 0.3497433662414551 s.
# Reading all forcing files took: 0.2666306495666504 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/RMNP_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/RMNP_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/RMNP_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/RMNP_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/RMNP_light_use_boxplots_bins_nonuniform.png
# Making these plots for RMNP took :  7.9682841300964355 s.
# ---------------------------
# Making plots for STER
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.6994807720184326 s.
# Reading all observation files took: 0.3089933395385742 s.
# Reading all forcing files took: 0.2438204288482666 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/STER_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/STER_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/STER_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/STER_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/STER_light_use_boxplots_bins_nonuniform.png
# Making these plots for STER took :  8.752529621124268 s.
# ---------------------------
# Making plots for CLBJ
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.1209981441497803 s.
# Reading all observation files took: 0.3025696277618408 s.
# Reading all forcing files took: 0.2940394878387451 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/CLBJ_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/CLBJ_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/CLBJ_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/CLBJ_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/CLBJ_light_use_boxplots_bins_nonuniform.png
# Making these plots for CLBJ took :  7.946357011795044 s.
# ---------------------------
# Making plots for OAES
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.7358312606811523 s.
# Reading all observation files took: 0.4018442630767822 s.
# Reading all forcing files took: 0.26686596870422363 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/OAES_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/OAES_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/OAES_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/OAES_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/OAES_light_use_boxplots_bins_nonuniform.png
# Making these plots for OAES took :  8.453291416168213 s.
# ---------------------------
# Making plots for YELL
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 0.9778032302856445 s.
# Reading all observation files took: 2.12424635887146 s.
# Reading all forcing files took: 0.24132585525512695 s.
# Length of values (10416) does not match length of index (8928)
# THIS SITE FAILED: YELL
# ---------------------------
# Making plots for MOAB
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 0.8900671005249023 s.
# Reading all observation files took: 1.027966022491455 s.
# Reading all forcing files took: 0.25677490234375 s.
# Length of values (11904) does not match length of index (8928)
# THIS SITE FAILED: MOAB
# ---------------------------
# Making plots for NIWO
# All Simulation files for all years: [ 0 files]
# no files to open
# THIS SITE FAILED: NIWO
# ---------------------------
# Making plots for JORN
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 2.2052972316741943 s.
# Reading all observation files took: 0.32183194160461426 s.
# Reading all forcing files took: 0.25121593475341797 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/JORN_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/JORN_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/JORN_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/JORN_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/JORN_light_use_boxplots_bins_nonuniform.png
# Making these plots for JORN took :  9.03991174697876 s.
# ---------------------------
# Making plots for SRER
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.0063977241516113 s.
# Reading all observation files took: 0.31553030014038086 s.
# Reading all forcing files took: 0.3263218402862549 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/SRER_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/SRER_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/SRER_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/SRER_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/SRER_light_use_boxplots_bins_nonuniform.png
# Making these plots for SRER took :  8.360135793685913 s.
# ---------------------------
# Making plots for ONAQ
# All Simulation files for all years: [ 124 files]
# Reading all simulation files took: 0.5509598255157471 s.
# Reading all observation files took: 0.2988903522491455 s.
# Reading all forcing files took: 0.2716505527496338 s.
# Length of values (11904) does not match length of index (5952)
# THIS SITE FAILED: ONAQ
# ---------------------------
# Making plots for ABBY
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 0.9590752124786377 s.
# Reading all observation files took: 0.37062692642211914 s.
# Reading all forcing files took: 0.2232069969177246 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/ABBY_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/ABBY_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/ABBY_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/ABBY_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/ABBY_light_use_boxplots_bins_nonuniform.png
# Making these plots for ABBY took :  7.71103572845459 s.
# ---------------------------
# Making plots for WREF
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 0.8188810348510742 s.
# Reading all observation files took: 1.0838611125946045 s.
# Reading all forcing files took: 0.27289271354675293 s.
# Length of values (11904) does not match length of index (8928)
# THIS SITE FAILED: WREF
# ---------------------------
# Making plots for SJER
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 0.8167428970336914 s.
# Reading all observation files took: 0.26970505714416504 s.
# Reading all forcing files took: 0.1843552589416504 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/SJER_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/SJER_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/SJER_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/SJER_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/SJER_light_use_boxplots_bins_nonuniform.png
# Making these plots for SJER took :  7.04860782623291 s.
# ---------------------------
# Making plots for SOAP
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.0092511177062988 s.
# Reading all observation files took: 0.31401920318603516 s.
# Reading all forcing files took: 0.2355635166168213 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/SOAP_light_use_curve_scatter.png
# Inputs must not be empty.
# THIS SITE FAILED: SOAP
# ---------------------------
# Making plots for TEAK
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 1.5897245407104492 s.
# Reading all observation files took: 0.33400845527648926 s.
# Reading all forcing files took: 0.24082589149475098 s.
# Length of values (11904) does not match length of index (8928)
# THIS SITE FAILED: TEAK
# ---------------------------
# Making plots for TOOL
# All Simulation files for all years: [ 124 files]
# Reading all simulation files took: 0.5430521965026855 s.
# Reading all observation files took: 0.32317662239074707 s.
# Reading all forcing files took: 0.2272031307220459 s.
# Length of values (11904) does not match length of index (5952)
# THIS SITE FAILED: TOOL
# ---------------------------
# Making plots for BARR
# All Simulation files for all years: [ 186 files]
# Reading all simulation files took: 0.8854873180389404 s.
# Reading all observation files took: 0.3032538890838623 s.
# Reading all forcing files took: 0.27799367904663086 s.
# Length of values (11904) does not match length of index (8928)
# THIS SITE FAILED: BARR
# ---------------------------
# Making plots for BONA
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.0947926044464111 s.
# Reading all observation files took: 0.2867295742034912 s.
# Reading all forcing files took: 0.25420403480529785 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/BONA_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/BONA_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/BONA_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/BONA_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/BONA_light_use_boxplots_bins_nonuniform.png
# Making these plots for BONA took :  8.729828834533691 s.
# ---------------------------
# Making plots for DEJU
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.0410172939300537 s.
# Reading all observation files took: 0.3380904197692871 s.
# Reading all forcing files took: 0.23624324798583984 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/DEJU_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/DEJU_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/DEJU_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/DEJU_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/DEJU_light_use_boxplots_bins_nonuniform.png
# Making these plots for DEJU took :  7.847367525100708 s.
# ---------------------------
# Making plots for HEAL
# All Simulation files for all years: [ 248 files]
# Reading all simulation files took: 1.0567374229431152 s.
# Reading all observation files took: 0.3727233409881592 s.
# Reading all forcing files took: 0.266463041305542 s.
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter/png/HEAL_light_use_curve_scatter.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_curve_scatter_fitted_log_line/png/HEAL_light_use_curve_scatter_fitted_log_line.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/png/HEAL_light_use_curve__bins_boxplots_uniform.png
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_uniform/pdf/HEAL_light_use_curve_bins_boxplots_uniform.pdf
# Saving /glade/work/wwieder/neon_vis_plots/paper_plots_final/light_use_boxplots_bins_nonuniform/png/HEAL_light_use_boxplots_bins_nonuniform.png
# Making these plots for HEAL took :  7.780720472335815 s.
# ---------------------------
# Making plots for PUUM
# All Simulation files for all years: [ 0 files]
# no files to open
# THIS SITE FAILED: PUUM
# Making plots for  14 sites failed :
# GUAN
# LAJA
# MLBS
# LENO
# YELL
# MOAB
# NIWO
# ONAQ
# WREF
# SOAP
# TEAK
# TOOL
# BARR
# PUUM
